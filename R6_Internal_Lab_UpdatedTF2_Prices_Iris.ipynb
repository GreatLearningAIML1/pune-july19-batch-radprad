# %% [markdown]
# ## Linear Classifier in TensorFlow
# Using Low Level API in Eager Execution mode

# %% [markdown]
# ### Load tensorflow

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
import tensorflow as tf

# %%
import numpy as np
np.random.seed(7)

# %%
#Enable Eager Execution if using tensflow version < 2.0
#From tensorflow v2.0 onwards, Eager Execution will be enabled by default

# %% [markdown]
# ### Collect Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/prices.csv')

# %% [markdown]
# ### Check all columns in the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
# date      851264 non-null object
# symbol    851264 non-null object
# open      851264 non-null float64
# close     851264 non-null float64
# low       851264 non-null float64
# high      851264 non-null float64
# volume    851264 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 45.5+ MB

# %% [markdown]
# ### Drop columns `date` and  `symbol`

# %%
data.drop(['date','symbol'],axis=1,inplace=True)

# %%
data.head()
# Out:
#          open       close         low        high     volume
# 0  123.430000  125.839996  122.309998  126.250000  2163600.0
# 1  125.239998  119.980003  119.940002  125.540001  2386400.0
# 2  116.379997  114.949997  114.930000  119.739998  2489500.0
# 3  115.480003  116.620003  113.500000  117.440002  2006300.0
# 4  117.010002  114.970001  114.089996  117.330002  1408600.0

# %% [markdown]
# ### Consider only first 1000 rows in the dataset for building feature set and target set
# Target 'Volume' has very high values. Divide 'Volume' by 1000,000

# %%
df_1000=data.head(1000)

# %%
df_1000['volume']=df_1000['volume']/1000000
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_1000.head()
# Out:
#          open       close         low        high  volume
# 0  123.430000  125.839996  122.309998  126.250000  2.1636
# 1  125.239998  119.980003  119.940002  125.540001  2.3864
# 2  116.379997  114.949997  114.930000  119.739998  2.4895
# 3  115.480003  116.620003  113.500000  117.440002  2.0063
# 4  117.010002  114.970001  114.089996  117.330002  1.4086

# %% [markdown]
# ### Divide the data into train and test sets

# %%
from sklearn.model_selection import train_test_split
# split into input (X) and output (Y) variables

# %%
X=df_1000.iloc[:,0:4]
Y = df_1000.iloc[:,4]
train_x,test_x,train_y,test_y=train_test_split(X,Y,test_size=.30,random_state=2)

# %% [markdown]
# #### Convert Training and Test Data to numpy float32 arrays

# %%
train_x =np.array(train_x).astype('float32')
test_x = np.array(test_x).astype('float32')
train_y =np.array(train_y).astype('float32')
test_y = np.array(test_y).astype('float32')

# %%
train_y.shape
# Out:
# (700,)

# %% [markdown]
# ### Normalize the data
# You can use Normalizer from sklearn.preprocessing

# %%
from sklearn.preprocessing import Normalizer

transformer = Normalizer()
train_x = transformer.fit_transform(train_x)
test_x = transformer.transform(test_x)
train_y=train_y.reshape(-1,1)

# %% [markdown]
# ## Building the Model in tensorflow

# %% [markdown]
# 1.Define Weights and Bias, use tf.zeros to initialize weights and Bias

# %%
#We are initializing weights and Bias of (Input-Hidden Layer)
w1 = tf.Variable( tf.random.normal( [4,1] ) )
b1 = tf.Variable( tf.random.normal( [1] ) )

# %% [markdown]
# 2.Define a function to calculate prediction

# %%
def prediction(X_train,W,B):
  out = tf.matmul( X_train,W ) + B
  return out

# %% [markdown]
# 3.Loss (Cost) Function [Mean square error]

# %%
def loss(predicted_y, desired_y):
  return tf.reduce_mean(tf.square(predicted_y - desired_y))

# %% [markdown]
# 4.Function to train the Model
#
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
def train(x, y_actual, w, b, learning_rate=0.01):
    
    # Record mathematical operations on 'tape' to calculate loss
    with tf.GradientTape() as t:
        t.watch([w,b])
        current_prediction = prediction(x, w, b)
        current_loss = loss(y_actual, current_prediction)
    
    # Calculate Gradients for Loss with respect to Weights and Bias
    dw, db = t.gradient(current_loss,[w, b])
    
    # Update Weights and Bias
    w = w - learning_rate * dw
    b = b - learning_rate * db
    
    return w, b

# %% [markdown]
# ## Train the model for 100 epochs
# 1. Observe the training loss at every iteration
# 2. Observe Train loss at every 5th iteration

# %%
for i in range(100):
    i=i+5    
    w1, b1 = train(train_x, train_y, w1, b1)
    print('Current Training Loss on iteration', i, loss(train_y, prediction(train_x, w1, b1)))
# Out:
# ('Current Training Loss on iteration', 5, <tf.Tensor: id=70, shape=(), dtype=float32, numpy=272.3455>)
# ('Current Training Loss on iteration', 6, <tf.Tensor: id=111, shape=(), dtype=float32, numpy=268.1385>)
# ('Current Training Loss on iteration', 7, <tf.Tensor: id=152, shape=(), dtype=float32, numpy=264.2614>)
# ('Current Training Loss on iteration', 8, <tf.Tensor: id=193, shape=(), dtype=float32, numpy=260.68826>)
# ('Current Training Loss on iteration', 9, <tf.Tensor: id=234, shape=(), dtype=float32, numpy=257.39523>)
# ('Current Training Loss on iteration', 10, <tf.Tensor: id=275, shape=(), dtype=float32, numpy=254.3604>)
# ('Current Training Loss on iteration', 11, <tf.Tensor: id=316, shape=(), dtype=float32, numpy=251.56343>)
# ('Current Training Loss on iteration', 12, <tf.Tensor: id=357, shape=(), dtype=float32, numpy=248.98582>)
# ('Current Training Loss on iteration', 13, <tf.Tensor: id=398, shape=(), dtype=float32, numpy=246.61028>)
# ('Current Training Loss on iteration', 14, <tf.Tensor: id=439, shape=(), dtype=float32, numpy=244.42094>)
# ('Current Training Loss on iteration', 15, <tf.Tensor: id=480, shape=(), dtype=float32, numpy=242.40321>)
# ('Current Training Loss on iteration', 16, <tf.Tensor: id=521, shape=(), dtype=float32, numpy=240.54373>)
# ('Current Training Loss on iteration', 17, <tf.Tensor: id=562, shape=(), dtype=float32, numpy=238.83>)
# ('Current Training Loss on iteration', 18, <tf.Tensor: id=603, shape=(), dtype=float32, numpy=237.25063>)
# ('Current Training Loss on iteration', 19, <tf.Tensor: id=644, shape=(), dtype=float32, numpy=235.79509>)
# ('Current Training Loss on iteration', 20, <tf.Tensor: id=685, shape=(), dtype=float32, numpy=234.45357>)
# ('Current Training Loss on iteration', 21, <tf.Tensor: id=726, shape=(), dtype=float32, numpy=233.21735>)
# ('Current Training Loss on iteration', 22, <tf.Tensor: id=767, shape=(), dtype=float32, numpy=232.07794>)
# ('Current Training Loss on iteration', 23, <tf.Tensor: id=808, shape=(), dtype=float32, numpy=231.02798>)
# ('Current Training Loss on iteration', 24, <tf.Tensor: id=849, shape=(), dtype=float32, numpy=230.06024>)
# ('Current Training Loss on iteration', 25, <tf.Tensor: id=890, shape=(), dtype=float32, numpy=229.16841>)
# ('Current Training Loss on iteration', 26, <tf.Tensor: id=931, shape=(), dtype=float32, numpy=228.34647>)
# ('Current Training Loss on iteration', 27, <tf.Tensor: id=972, shape=(), dtype=float32, numpy=227.58897>)
# ('Current Training Loss on iteration', 28, <tf.Tensor: id=1013, shape=(), dtype=float32, numpy=226.89087>)
# ('Current Training Loss on iteration', 29, <tf.Tensor: id=1054, shape=(), dtype=float32, numpy=226.24753>)
# ('Current Training Loss on iteration', 30, <tf.Tensor: id=1095, shape=(), dtype=float32, numpy=225.65457>)
# ('Current Training Loss on iteration', 31, <tf.Tensor: id=1136, shape=(), dtype=float32, numpy=225.10811>)
# ('Current Training Loss on iteration', 32, <tf.Tensor: id=1177, shape=(), dtype=float32, numpy=224.6045>)
# ('Current Training Loss on iteration', 33, <tf.Tensor: id=1218, shape=(), dtype=float32, numpy=224.14035>)
# ('Current Training Loss on iteration', 34, <tf.Tensor: id=1259, shape=(), dtype=float32, numpy=223.71263>)
# ('Current Training Loss on iteration', 35, <tf.Tensor: id=1300, shape=(), dtype=float32, numpy=223.31844>)
# ('Current Training Loss on iteration', 36, <tf.Tensor: id=1341, shape=(), dtype=float32, numpy=222.95514>)
# ('Current Training Loss on iteration', 37, <tf.Tensor: id=1382, shape=(), dtype=float32, numpy=222.62029>)
# ('Current Training Loss on iteration', 38, <tf.Tensor: id=1423, shape=(), dtype=float32, numpy=222.31168>)
# ('Current Training Loss on iteration', 39, <tf.Tensor: id=1464, shape=(), dtype=float32, numpy=222.0273>)
# ('Current Training Loss on iteration', 40, <tf.Tensor: id=1505, shape=(), dtype=float32, numpy=221.76523>)
# ('Current Training Loss on iteration', 41, <tf.Tensor: id=1546, shape=(), dtype=float32, numpy=221.52368>)
# ('Current Training Loss on iteration', 42, <tf.Tensor: id=1587, shape=(), dtype=float32, numpy=221.30112>)
# ('Current Training Loss on iteration', 43, <tf.Tensor: id=1628, shape=(), dtype=float32, numpy=221.09593>)
# ('Current Training Loss on iteration', 44, <tf.Tensor: id=1669, shape=(), dtype=float32, numpy=220.90688>)
# ('Current Training Loss on iteration', 45, <tf.Tensor: id=1710, shape=(), dtype=float32, numpy=220.73265>)
# ('Current Training Loss on iteration', 46, <tf.Tensor: id=1751, shape=(), dtype=float32, numpy=220.57208>)
# ('Current Training Loss on iteration', 47, <tf.Tensor: id=1792, shape=(), dtype=float32, numpy=220.42401>)
# ('Current Training Loss on iteration', 48, <tf.Tensor: id=1833, shape=(), dtype=float32, numpy=220.28763>)
# ('Current Training Loss on iteration', 49, <tf.Tensor: id=1874, shape=(), dtype=float32, numpy=220.16194>)
# ('Current Training Loss on iteration', 50, <tf.Tensor: id=1915, shape=(), dtype=float32, numpy=220.04605>)
# ('Current Training Loss on iteration', 51, <tf.Tensor: id=1956, shape=(), dtype=float32, numpy=219.9393>)
# ('Current Training Loss on iteration', 52, <tf.Tensor: id=1997, shape=(), dtype=float32, numpy=219.84091>)
# ('Current Training Loss on iteration', 53, <tf.Tensor: id=2038, shape=(), dtype=float32, numpy=219.75023>)
# ('Current Training Loss on iteration', 54, <tf.Tensor: id=2079, shape=(), dtype=float32, numpy=219.66667>)
# ('Current Training Loss on iteration', 55, <tf.Tensor: id=2120, shape=(), dtype=float32, numpy=219.58961>)
# ('Current Training Loss on iteration', 56, <tf.Tensor: id=2161, shape=(), dtype=float32, numpy=219.51862>)
# ('Current Training Loss on iteration', 57, <tf.Tensor: id=2202, shape=(), dtype=float32, numpy=219.45322>)
# ('Current Training Loss on iteration', 58, <tf.Tensor: id=2243, shape=(), dtype=float32, numpy=219.39294>)
# ('Current Training Loss on iteration', 59, <tf.Tensor: id=2284, shape=(), dtype=float32, numpy=219.33739>)
# ('Current Training Loss on iteration', 60, <tf.Tensor: id=2325, shape=(), dtype=float32, numpy=219.28616>)
# ('Current Training Loss on iteration', 61, <tf.Tensor: id=2366, shape=(), dtype=float32, numpy=219.2389>)
# ('Current Training Loss on iteration', 62, <tf.Tensor: id=2407, shape=(), dtype=float32, numpy=219.19545>)
# ('Current Training Loss on iteration', 63, <tf.Tensor: id=2448, shape=(), dtype=float32, numpy=219.15535>)
# ('Current Training Loss on iteration', 64, <tf.Tensor: id=2489, shape=(), dtype=float32, numpy=219.11841>)
# ('Current Training Loss on iteration', 65, <tf.Tensor: id=2530, shape=(), dtype=float32, numpy=219.08443>)
# ('Current Training Loss on iteration', 66, <tf.Tensor: id=2571, shape=(), dtype=float32, numpy=219.05301>)
# ('Current Training Loss on iteration', 67, <tf.Tensor: id=2612, shape=(), dtype=float32, numpy=219.02406>)
# ('Current Training Loss on iteration', 68, <tf.Tensor: id=2653, shape=(), dtype=float32, numpy=218.99745>)
# ('Current Training Loss on iteration', 69, <tf.Tensor: id=2694, shape=(), dtype=float32, numpy=218.97289>)
# ('Current Training Loss on iteration', 70, <tf.Tensor: id=2735, shape=(), dtype=float32, numpy=218.95024>)
# ('Current Training Loss on iteration', 71, <tf.Tensor: id=2776, shape=(), dtype=float32, numpy=218.92935>)
# ('Current Training Loss on iteration', 72, <tf.Tensor: id=2817, shape=(), dtype=float32, numpy=218.91011>)
# ('Current Training Loss on iteration', 73, <tf.Tensor: id=2858, shape=(), dtype=float32, numpy=218.89243>)
# ('Current Training Loss on iteration', 74, <tf.Tensor: id=2899, shape=(), dtype=float32, numpy=218.87602>)
# ('Current Training Loss on iteration', 75, <tf.Tensor: id=2940, shape=(), dtype=float32, numpy=218.86101>)
# ('Current Training Loss on iteration', 76, <tf.Tensor: id=2981, shape=(), dtype=float32, numpy=218.84712>)
# ('Current Training Loss on iteration', 77, <tf.Tensor: id=3022, shape=(), dtype=float32, numpy=218.83435>)
# ('Current Training Loss on iteration', 78, <tf.Tensor: id=3063, shape=(), dtype=float32, numpy=218.82257>)
# ('Current Training Loss on iteration', 79, <tf.Tensor: id=3104, shape=(), dtype=float32, numpy=218.81169>)
# ('Current Training Loss on iteration', 80, <tf.Tensor: id=3145, shape=(), dtype=float32, numpy=218.8017>)
# ('Current Training Loss on iteration', 81, <tf.Tensor: id=3186, shape=(), dtype=float32, numpy=218.79248>)
# ('Current Training Loss on iteration', 82, <tf.Tensor: id=3227, shape=(), dtype=float32, numpy=218.78395>)
# ('Current Training Loss on iteration', 83, <tf.Tensor: id=3268, shape=(), dtype=float32, numpy=218.7761>)
# ('Current Training Loss on iteration', 84, <tf.Tensor: id=3309, shape=(), dtype=float32, numpy=218.7689>)
# ('Current Training Loss on iteration', 85, <tf.Tensor: id=3350, shape=(), dtype=float32, numpy=218.76225>)
# ('Current Training Loss on iteration', 86, <tf.Tensor: id=3391, shape=(), dtype=float32, numpy=218.75612>)
# ('Current Training Loss on iteration', 87, <tf.Tensor: id=3432, shape=(), dtype=float32, numpy=218.75047>)
# ('Current Training Loss on iteration', 88, <tf.Tensor: id=3473, shape=(), dtype=float32, numpy=218.74522>)
# ('Current Training Loss on iteration', 89, <tf.Tensor: id=3514, shape=(), dtype=float32, numpy=218.74045>)
# ('Current Training Loss on iteration', 90, <tf.Tensor: id=3555, shape=(), dtype=float32, numpy=218.73601>)
# ('Current Training Loss on iteration', 91, <tf.Tensor: id=3596, shape=(), dtype=float32, numpy=218.7319>)
# ('Current Training Loss on iteration', 92, <tf.Tensor: id=3637, shape=(), dtype=float32, numpy=218.72815>)
# ('Current Training Loss on iteration', 93, <tf.Tensor: id=3678, shape=(), dtype=float32, numpy=218.72472>)
# ('Current Training Loss on iteration', 94, <tf.Tensor: id=3719, shape=(), dtype=float32, numpy=218.7215>)
# ('Current Training Loss on iteration', 95, <tf.Tensor: id=3760, shape=(), dtype=float32, numpy=218.71857>)
# ('Current Training Loss on iteration', 96, <tf.Tensor: id=3801, shape=(), dtype=float32, numpy=218.71577>)
# ('Current Training Loss on iteration', 97, <tf.Tensor: id=3842, shape=(), dtype=float32, numpy=218.7133>)
# ('Current Training Loss on iteration', 98, <tf.Tensor: id=3883, shape=(), dtype=float32, numpy=218.71103>)
# ('Current Training Loss on iteration', 99, <tf.Tensor: id=3924, shape=(), dtype=float32, numpy=218.70886>)
# ('Current Training Loss on iteration', 100, <tf.Tensor: id=3965, shape=(), dtype=float32, numpy=218.70694>)
# ('Current Training Loss on iteration', 101, <tf.Tensor: id=4006, shape=(), dtype=float32, numpy=218.70511>)
# ('Current Training Loss on iteration', 102, <tf.Tensor: id=4047, shape=(), dtype=float32, numpy=218.70346>)
# ('Current Training Loss on iteration', 103, <tf.Tensor: id=4088, shape=(), dtype=float32, numpy=218.70187>)
# ('Current Training Loss on iteration', 104, <tf.Tensor: id=4129, shape=(), dtype=float32, numpy=218.70052>)

# %% [markdown]
# ### Get the shapes and values of W and b

# %%
w1
# Out:
# <tf.Tensor: id=4118, shape=(4, 1), dtype=float32, numpy=
# array([[3.0095284 ],
#        [0.79824096],
#        [2.6107752 ],
#        [2.1290803 ]], dtype=float32)>

# %%
b1
# Out:
# <tf.Tensor: id=4121, shape=(1,), dtype=float32, numpy=array([1.2526028], dtype=float32)>

# %% [markdown]
# ### Model Prediction on 1st Examples in Test Dataset

# %%
y_pred=prediction(test_x,w1,b1)
print(y_pred[0])
print(test_y[0])
# Out:
# tf.Tensor([5.5214844], shape=(1,), dtype=float32)
# 0.9716

# %%
print("predicted for first value",y_pred[0])
print("actual for first value",test_y[0])
# Out:
# ('predicted for first value', <tf.Tensor: id=4140, shape=(1,), dtype=float32, numpy=array([5.5214844], dtype=float32)>)
# ('actual for first value', 0.9716)

# %% [markdown]
# ## Classification using tf.Keras
#
# In this exercise, we will build a Deep Neural Network using tf.Keras. We will use Iris Dataset for this exercise.

# %% [markdown]
# ### Load the given Iris data using pandas (Iris.csv)

# %%
   iris = pd.read_csv('/content/drive/My Drive/Colab Notebooks/11_Iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.1+ KB

# %%
iris.drop(['Id'],axis=1,inplace=True)

# %% [markdown]
# ### Target set has different categories. So, Label encode them. And convert into one-hot vectors using get_dummies in pandas.

# %%
  
iris_encode=pd.get_dummies(iris, drop_first=False)
iris_encode.head()
# Out:
#    SepalLengthCm  SepalWidthCm  ...  Species_Iris-versicolor  Species_Iris-virginica
# 0            5.1           3.5  ...                        0                       0
# 1            4.9           3.0  ...                        0                       0
# 2            4.7           3.2  ...                        0                       0
# 3            4.6           3.1  ...                        0                       0
# 4            5.0           3.6  ...                        0                       0
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Splitting the data into feature set and target set

# %%
x = iris_encode.iloc[:,:4]
y = iris_encode.iloc[:,4:7]

train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# %% [markdown]
# ###  Building Model in tf.keras
#
# Build a Linear Classifier model  <br>
# 1.  Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3<br>
# 2. Apply Softmax on Dense Layer outputs <br>
# 3. Use SGD as Optimizer
# 4. Use categorical_crossentropy as loss function

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold

# %%
# baseline model
def create_baseline():
	# create model
  model = Sequential()
  model.add(Dense(10, input_shape=(4,), activation='softmax', name='fc1'))
  #model.add(Dense(10, activation='softmax', name='fc2'))
  model.add(Dense(3, activation='softmax', name='output'))
  model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
# baseline model
def hiddenlayer_2():
	# create model
  model = Sequential()
  model.add(Dense(10, input_shape=(4,), activation='softmax', name='fc1'))
  model.add(Dense(3, activation='softmax', name='fc2'))
  model.add(Dense(3, activation='softmax', name='output'))
  model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ### Model Training

# %%
model = create_baseline()
print('Neural Network Model Summary: ')
print(model.summary())

# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)
# Out:
# Neural Network Model Summary:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fc1 (Dense)                  (None, 10)                50
# _________________________________________________________________
# output (Dense)               (None, 3)                 33
# =================================================================
# Total params: 83
# Trainable params: 83
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <type 'NoneType'>
# Train on 120 samples
# Epoch 1/200
# 120/120 - 0s - loss: 1.1237 - accuracy: 0.3167
# Epoch 2/200
# 120/120 - 0s - loss: 1.0878 - accuracy: 0.3167
# Epoch 3/200
# 120/120 - 0s - loss: 1.0541 - accuracy: 0.3167
# Epoch 4/200
# 120/120 - 0s - loss: 1.0227 - accuracy: 0.3167
# Epoch 5/200
# 120/120 - 0s - loss: 0.9936 - accuracy: 0.5167
# Epoch 44/200
# 120/120 - 0s - loss: 0.5993 - accuracy: 0.7000
# Epoch 45/200
# 120/120 - 0s - loss: 0.5957 - accuracy: 0.7167
# Epoch 46/200
# 120/120 - 0s - loss: 0.5923 - accuracy: 0.7000
# Epoch 47/200
# 120/120 - 0s - loss: 0.5892 - accuracy: 0.7000
# Epoch 48/200
# 120/120 - 0s - loss: 0.5859 - accuracy: 0.7250
# Epoch 49/200
# 120/120 - 0s - loss: 0.5829 - accuracy: 0.7000
# Epoch 50/200
# 120/120 - 0s - loss: 0.5798 - accuracy: 0.7083
# Epoch 51/200
# 120/120 - 0s - loss: 0.5771 - accuracy: 0.7083
# Epoch 52/200
# 120/120 - 0s - loss: 0.5739 - accuracy: 0.7167
# Epoch 53/200
# 120/120 - 0s - loss: 0.5714 - accuracy: 0.7250
# Epoch 54/200
# 120/120 - 0s - loss: 0.5687 - accuracy: 0.7250
# Epoch 55/200
# 120/120 - 0s - loss: 0.5664 - accuracy: 0.7250
# Epoch 56/200
# 120/120 - 0s - loss: 0.5640 - accuracy: 0.7250
# Epoch 57/200
# 120/120 - 0s - loss: 0.5617 - accuracy: 0.7250
# Epoch 58/200
# 120/120 - 0s - loss: 0.5598 - accuracy: 0.7250
# Epoch 59/200
# 120/120 - 0s - loss: 0.5570 - accuracy: 0.7250
# Epoch 60/200
# 120/120 - 0s - loss: 0.5552 - accuracy: 0.7000
# Epoch 61/200
# 120/120 - 0s - loss: 0.5534 - accuracy: 0.7250
# Epoch 62/200
# 120/120 - 0s - loss: 0.5511 - accuracy: 0.7250
# Epoch 63/200
# 120/120 - 0s - loss: 0.5490 - accuracy: 0.7250
# Epoch 64/200
# 120/120 - 0s - loss: 0.5473 - accuracy: 0.7250
# Epoch 65/200
# 120/120 - 0s - loss: 0.5455 - accuracy: 0.7250
# Epoch 66/200
# 120/120 - 0s - loss: 0.5436 - accuracy: 0.7250
# Epoch 67/200
# 120/120 - 0s - loss: 0.5417 - accuracy: 0.7250
# Epoch 68/200
# 120/120 - 0s - loss: 0.5403 - accuracy: 0.7250
# Epoch 69/200
# 120/120 - 0s - loss: 0.5386 - accuracy: 0.7250
# Epoch 70/200
# 120/120 - 0s - loss: 0.5369 - accuracy: 0.7250
# Epoch 71/200
# 120/120 - 0s - loss: 0.5353 - accuracy: 0.7333
# Epoch 72/200
# 120/120 - 0s - loss: 0.5339 - accuracy: 0.7250
# Epoch 73/200
# 120/120 - 0s - loss: 0.5320 - accuracy: 0.7250
# Epoch 74/200
# 120/120 - 0s - loss: 0.5308 - accuracy: 0.7333
# Epoch 75/200
# 120/120 - 0s - loss: 0.5294 - accuracy: 0.7250
# Epoch 76/200
# 120/120 - 0s - loss: 0.5281 - accuracy: 0.7333
# Epoch 77/200
# 120/120 - 0s - loss: 0.5266 - accuracy: 0.7333
# Epoch 78/200
# 120/120 - 0s - loss: 0.5252 - accuracy: 0.7333
# Epoch 79/200
# 120/120 - 0s - loss: 0.5240 - accuracy: 0.7333
# Epoch 80/200
# 120/120 - 0s - loss: 0.5229 - accuracy: 0.7250
# Epoch 81/200
# Epoch 194/200
# 120/120 - 0s - loss: 0.4262 - accuracy: 0.9000
# Epoch 195/200
# 120/120 - 0s - loss: 0.4249 - accuracy: 0.8917
# Epoch 196/200
# 120/120 - 0s - loss: 0.4248 - accuracy: 0.9167
# Epoch 197/200
# 120/120 - 0s - loss: 0.4226 - accuracy: 0.9167
# Epoch 198/200
# 120/120 - 0s - loss: 0.4224 - accuracy: 0.9000
# Epoch 199/200
# 120/120 - 0s - loss: 0.4215 - accuracy: 0.9167
# Epoch 200/200
# 120/120 - 0s - loss: 0.4208 - accuracy: 0.9083

# %% [markdown]
# ### Model Prediction

# %%
# Test on unseen data

results = model.evaluate(test_x, test_y)
print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <type 'NoneType'>
# 30/30 [==============================] - 0s 593us/sample - loss: 0.4963 - accuracy: 0.8333
# Final test set loss: 0.496291
# Final test set accuracy: 0.833333

# %% [markdown]
# ### Save the Model

# %%
model.save('//content/drive/My Drive/Colab Notebooks/iris_prediction_model.html')
# Out:
# WARNING:tensorflow:From /tensorflow-2.0.0/python2.7/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling __init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: //content/drive/My Drive/Colab Notebooks/iris_prediction_model.html/assets

# %% [markdown]
# ### Build and Train a Deep Neural network with 2 hidden layer  - Optional - For Practice
#
# Does it perform better than Linear Classifier? What could be the reason for difference in performance?

# %%
model = hiddenlayer_2()
print('Neural Network Model Summary: ')
print(model.summary())

# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)
results = model.evaluate(test_x, test_y)
print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# Neural Network Model Summary:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fc1 (Dense)                  (None, 10)                50
# _________________________________________________________________
# fc2 (Dense)                  (None, 3)                 33
# _________________________________________________________________
# output (Dense)               (None, 3)                 12
# =================================================================
# Total params: 95
# Trainable params: 95
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <type 'NoneType'>
# Train on 120 samples
# Epoch 1/200
# 120/120 - 0s - loss: 1.1189 - accuracy: 0.3583
# Epoch 2/200
# 120/120 - 0s - loss: 1.1107 - accuracy: 0.3583
# Epoch 3/200
# 120/120 - 0s - loss: 1.1040 - accuracy: 0.3583
# Epoch 4/200
# 120/120 - 0s - loss: 1.0972 - accuracy: 0.3583
# Epoch 5/200
# 120/120 - 0s - loss: 1.0921 - accuracy: 0.3583
# Epoch 6/200
# 120/120 - 0s - loss: 1.0873 - accuracy: 0.3583
# Epoch 7/200
# 120/120 - 0s - loss: 1.0829 - accuracy: 0.3583
# Epoch 8/200
# 120/120 - 0s - loss: 1.0791 - accuracy: 0.3583
# Epoch 9/200
# 120/120 - 0s - loss: 1.0754 - accuracy: 0.3583
# Epoch 10/200
# 120/120 - 0s - loss: 1.0720 - accuracy: 0.3667
# Epoch 11/200
# 120/120 - 0s - loss: 1.0686 - accuracy: 0.4333
# Epoch 12/200
# 120/120 - 0s - loss: 1.0647 - accuracy: 0.4000
# Epoch 13/200
# 120/120 - 0s - loss: 1.0617 - accuracy: 0.4250
# Epoch 14/200
# 120/120 - 0s - loss: 1.0589 - accuracy: 0.5583
# Epoch 15/200
# 120/120 - 0s - loss: 1.0553 - accuracy: 0.6500
# Epoch 16/200
# 120/120 - 0s - loss: 1.0519 - accuracy: 0.6167
# Epoch 17/200
# 120/120 - 0s - loss: 1.0481 - accuracy: 0.6833
# Epoch 18/200
# 120/120 - 0s - loss: 1.0452 - accuracy: 0.6750
# Epoch 19/200
# 120/120 - 0s - loss: 1.0406 - accuracy: 0.6750
# Epoch 20/200
# 120/120 - 0s - loss: 1.0372 - accuracy: 0.6833
# Epoch 21/200
# 120/120 - 0s - loss: 1.0333 - accuracy: 0.6750
# Epoch 22/200
# 120/120 - 0s - loss: 1.0296 - accuracy: 0.6833
# Epoch 23/200
# 120/120 - 0s - loss: 1.0251 - accuracy: 0.6833
# Epoch 24/200
# 120/120 - 0s - loss: 1.0213 - accuracy: 0.6833
# Epoch 25/200
# 120/120 - 0s - loss: 1.0163 - accuracy: 0.6833
# Epoch 26/200
# 120/120 - 0s - loss: 1.0119 - accuracy: 0.6833
# Epoch 27/200
# 120/120 - 0s - loss: 1.0072 - accuracy: 0.6833
# Epoch 28/200
# 120/120 - 0s - loss: 1.0022 - accuracy: 0.6833
# Epoch 29/200
# 120/120 - 0s - loss: 0.9975 - accuracy: 0.6833
# Epoch 30/200
# 120/120 - 0s - loss: 0.9925 - accuracy: 0.6833
# Epoch 31/200
# 120/120 - 0s - loss: 0.9868 - accuracy: 0.6833
# Epoch 32/200
# 120/120 - 0s - loss: 0.9818 - accuracy: 0.6833
# Epoch 33/200
# 120/120 - 0s - loss: 0.9760 - accuracy: 0.6833
# Epoch 34/200
# 120/120 - 0s - loss: 0.9703 - accuracy: 0.6833
# Epoch 35/200
# 120/120 - 0s - loss: 0.9640 - accuracy: 0.6833
# Epoch 36/200
# 120/120 - 0s - loss: 0.9582 - accuracy: 0.6833
# Epoch 37/200
# 120/120 - 0s - loss: 0.9521 - accuracy: 0.6833
# Epoch 38/200
# 120/120 - 0s - loss: 0.9458 - accuracy: 0.6833
# Epoch 39/200
# 120/120 - 0s - loss: 0.9391 - accuracy: 0.6833
# Epoch 40/200
# 120/120 - 0s - loss: 0.9328 - accuracy: 0.6833
# Epoch 41/200
# 120/120 - 0s - loss: 0.9259 - accuracy: 0.6833
# Epoch 42/200
# 120/120 - 0s - loss: 0.9194 - accuracy: 0.6833
# Epoch 43/200
# 120/120 - 0s - loss: 0.9126 - accuracy: 0.6833
# Epoch 44/200
# 120/120 - 0s - loss: 0.9057 - accuracy: 0.6833
# Epoch 45/200
# 120/120 - 0s - loss: 0.8988 - accuracy: 0.6833
# Epoch 46/200
# 120/120 - 0s - loss: 0.8916 - accuracy: 0.6833
# Epoch 47/200
# 120/120 - 0s - loss: 0.8846 - accuracy: 0.6833
# Epoch 48/200
# 120/120 - 0s - loss: 0.8779 - accuracy: 0.6833
# Epoch 49/200
# 120/120 - 0s - loss: 0.8707 - accuracy: 0.6833
# Epoch 50/200
# 120/120 - 0s - loss: 0.8631 - accuracy: 0.6833
# Epoch 51/200
# 120/120 - 0s - loss: 0.8557 - accuracy: 0.6833
# Epoch 52/200
# 120/120 - 0s - loss: 0.8489 - accuracy: 0.6833
# Epoch 53/200
# 120/120 - 0s - loss: 0.8416 - accuracy: 0.6833
# Epoch 54/200
# 120/120 - 0s - loss: 0.8345 - accuracy: 0.6833
# Epoch 55/200
# 120/120 - 0s - loss: 0.8271 - accuracy: 0.6833
# Epoch 56/200
# 120/120 - 0s - loss: 0.8205 - accuracy: 0.6833
# Epoch 57/200
# 120/120 - 0s - loss: 0.8128 - accuracy: 0.6833
# Epoch 58/200
# 120/120 - 0s - loss: 0.8063 - accuracy: 0.6833
# Epoch 59/200
# 120/120 - 0s - loss: 0.7988 - accuracy: 0.6833
# Epoch 60/200
# 120/120 - 0s - loss: 0.7921 - accuracy: 0.6833
# Epoch 61/200
# 120/120 - 0s - loss: 0.7848 - accuracy: 0.6833
# Epoch 62/200
# 120/120 - 0s - loss: 0.7782 - accuracy: 0.7000
# Epoch 63/200
# 120/120 - 0s - loss: 0.7716 - accuracy: 0.6833
# Epoch 64/200
# 120/120 - 0s - loss: 0.7646 - accuracy: 0.6917
# Epoch 65/200
# 120/120 - 0s - loss: 0.7578 - accuracy: 0.6833
# Epoch 66/200
# 120/120 - 0s - loss: 0.7514 - accuracy: 0.6917
# Epoch 67/200
# 120/120 - 0s - loss: 0.7449 - accuracy: 0.6917
# Epoch 68/200
# 120/120 - 0s - loss: 0.7385 - accuracy: 0.7000
# Epoch 69/200
# 120/120 - 0s - loss: 0.7321 - accuracy: 0.7083
# Epoch 70/200
# 120/120 - 0s - loss: 0.7261 - accuracy: 0.7000
# Epoch 71/200
# 120/120 - 0s - loss: 0.7200 - accuracy: 0.7000
# Epoch 72/200
# 120/120 - 0s - loss: 0.7137 - accuracy: 0.7000
# Epoch 73/200
# 120/120 - 0s - loss: 0.7082 - accuracy: 0.7000
# Epoch 74/200
# 120/120 - 0s - loss: 0.7023 - accuracy: 0.7083
# Epoch 75/200
# 120/120 - 0s - loss: 0.6968 - accuracy: 0.7083
# Epoch 76/200
# 120/120 - 0s - loss: 0.6909 - accuracy: 0.7083
# Epoch 77/200
# 120/120 - 0s - loss: 0.6856 - accuracy: 0.7083
# Epoch 78/200
# 120/120 - 0s - loss: 0.6804 - accuracy: 0.7083
# Epoch 79/200
# 120/120 - 0s - loss: 0.6752 - accuracy: 0.7083
# Epoch 80/200
# 120/120 - 0s - loss: 0.6701 - accuracy: 0.7083
# Epoch 81/200
# 120/120 - 0s - loss: 0.6650 - accuracy: 0.7083
# Epoch 82/200
# 120/120 - 0s - loss: 0.6604 - accuracy: 0.7333
# Epoch 83/200
# 120/120 - 0s - loss: 0.6558 - accuracy: 0.7167
# Epoch 84/200
# 120/120 - 0s - loss: 0.6507 - accuracy: 0.7167
# Epoch 85/200
# 120/120 - 0s - loss: 0.6462 - accuracy: 0.7250
# Epoch 86/200
# 120/120 - 0s - loss: 0.6421 - accuracy: 0.7083
# Epoch 87/200
# 120/120 - 0s - loss: 0.6377 - accuracy: 0.7333
# Epoch 88/200
# 120/120 - 0s - loss: 0.6334 - accuracy: 0.7250
# Epoch 89/200
# 120/120 - 0s - loss: 0.6293 - accuracy: 0.7250
# Epoch 90/200
# 120/120 - 0s - loss: 0.6256 - accuracy: 0.7417
# Epoch 91/200
# 120/120 - 0s - loss: 0.6209 - accuracy: 0.7250
# Epoch 92/200
# 120/120 - 0s - loss: 0.6175 - accuracy: 0.7417
# Epoch 93/200
# 120/120 - 0s - loss: 0.6138 - accuracy: 0.7417
# Epoch 94/200
# 120/120 - 0s - loss: 0.6100 - accuracy: 0.7417
# Epoch 95/200
# 120/120 - 0s - loss: 0.6063 - accuracy: 0.7583
# Epoch 96/200
# 120/120 - 0s - loss: 0.6031 - accuracy: 0.7333
# Epoch 97/200
# 120/120 - 0s - loss: 0.5994 - accuracy: 0.7417
# Epoch 98/200
# 120/120 - 0s - loss: 0.5964 - accuracy: 0.7417
# Epoch 99/200
# 120/120 - 0s - loss: 0.5928 - accuracy: 0.7667
# Epoch 100/200
# 120/120 - 0s - loss: 0.5897 - accuracy: 0.7417
# Epoch 101/200
# 120/120 - 0s - loss: 0.5868 - accuracy: 0.7500
# Epoch 102/200
# 120/120 - 0s - loss: 0.5836 - accuracy: 0.7583
# Epoch 103/200
# 120/120 - 0s - loss: 0.5806 - accuracy: 0.7500
# Epoch 104/200
# 120/120 - 0s - loss: 0.5779 - accuracy: 0.7500
# Epoch 105/200
# 120/120 - 0s - loss: 0.5751 - accuracy: 0.7667
# Epoch 106/200
# 120/120 - 0s - loss: 0.5724 - accuracy: 0.7500
# Epoch 107/200
# 120/120 - 0s - loss: 0.5699 - accuracy: 0.7667
# Epoch 108/200
# 120/120 - 0s - loss: 0.5672 - accuracy: 0.7500
# Epoch 109/200
# 120/120 - 0s - loss: 0.5649 - accuracy: 0.7500
# Epoch 110/200
# 120/120 - 0s - loss: 0.5622 - accuracy: 0.7583
# Epoch 111/200
# 120/120 - 0s - loss: 0.5598 - accuracy: 0.7833
# Epoch 112/200
# 120/120 - 0s - loss: 0.5576 - accuracy: 0.7750
# Epoch 113/200
# 120/120 - 0s - loss: 0.5554 - accuracy: 0.7417
# Epoch 114/200
# 120/120 - 0s - loss: 0.5530 - accuracy: 0.7917
# Epoch 115/200
# 120/120 - 0s - loss: 0.5506 - accuracy: 0.7833
# Epoch 116/200
# 120/120 - 0s - loss: 0.5487 - accuracy: 0.7833
# Epoch 117/200
# 120/120 - 0s - loss: 0.5466 - accuracy: 0.8083
# Epoch 118/200
# 120/120 - 0s - loss: 0.5446 - accuracy: 0.8083
# Epoch 119/200
# 120/120 - 0s - loss: 0.5429 - accuracy: 0.8000
# Epoch 120/200
# 120/120 - 0s - loss: 0.5407 - accuracy: 0.7917
# Epoch 121/200
# 120/120 - 0s - loss: 0.5387 - accuracy: 0.7833
# Epoch 122/200
# 120/120 - 0s - loss: 0.5366 - accuracy: 0.8167
# Epoch 123/200
# 120/120 - 0s - loss: 0.5348 - accuracy: 0.7833
# Epoch 124/200
# 120/120 - 0s - loss: 0.5333 - accuracy: 0.8250
# Epoch 125/200
# 120/120 - 0s - loss: 0.5312 - accuracy: 0.8083
# Epoch 126/200
# 120/120 - 0s - loss: 0.5303 - accuracy: 0.8250
# Epoch 127/200
# 120/120 - 0s - loss: 0.5284 - accuracy: 0.8083
# Epoch 128/200
# 120/120 - 0s - loss: 0.5266 - accuracy: 0.8083
# Epoch 129/200
# 120/120 - 0s - loss: 0.5251 - accuracy: 0.8000
# Epoch 130/200
# 120/120 - 0s - loss: 0.5232 - accuracy: 0.8333
# Epoch 131/200
# 120/120 - 0s - loss: 0.5218 - accuracy: 0.8250
# Epoch 132/200
# 120/120 - 0s - loss: 0.5204 - accuracy: 0.8167
# Epoch 133/200
# 120/120 - 0s - loss: 0.5191 - accuracy: 0.8250
# Epoch 134/200
# 120/120 - 0s - loss: 0.5176 - accuracy: 0.8167
# Epoch 135/200
# 120/120 - 0s - loss: 0.5158 - accuracy: 0.7917
# Epoch 136/200
# 120/120 - 0s - loss: 0.5138 - accuracy: 0.8417
# Epoch 137/200
# 120/120 - 0s - loss: 0.5130 - accuracy: 0.8083
# Epoch 138/200
# 120/120 - 0s - loss: 0.5112 - accuracy: 0.8333
# Epoch 139/200
# 120/120 - 0s - loss: 0.5108 - accuracy: 0.8333
# Epoch 140/200
# 120/120 - 0s - loss: 0.5090 - accuracy: 0.8333
# Epoch 141/200
# 120/120 - 0s - loss: 0.5081 - accuracy: 0.8333
# Epoch 142/200
# 120/120 - 0s - loss: 0.5063 - accuracy: 0.8250
# Epoch 143/200
# 120/120 - 0s - loss: 0.5058 - accuracy: 0.8250
# Epoch 144/200
# 120/120 - 0s - loss: 0.5045 - accuracy: 0.8083
# Epoch 145/200
# 120/120 - 0s - loss: 0.5019 - accuracy: 0.8583
# Epoch 146/200
# 120/120 - 0s - loss: 0.5003 - accuracy: 0.8167
# Epoch 147/200
# 120/120 - 0s - loss: 0.5004 - accuracy: 0.8500
# Epoch 148/200
# 120/120 - 0s - loss: 0.4989 - accuracy: 0.8167
# Epoch 149/200
# 120/120 - 0s - loss: 0.4983 - accuracy: 0.8333
# Epoch 150/200
# 120/120 - 0s - loss: 0.4963 - accuracy: 0.8667
# Epoch 151/200
# 120/120 - 0s - loss: 0.4962 - accuracy: 0.8333
# Epoch 152/200
# 120/120 - 0s - loss: 0.4948 - accuracy: 0.8417
# Epoch 153/200
# 120/120 - 0s - loss: 0.4937 - accuracy: 0.8333
# Epoch 154/200
# 120/120 - 0s - loss: 0.4915 - accuracy: 0.8333
# Epoch 155/200
# 120/120 - 0s - loss: 0.4910 - accuracy: 0.8417
# Epoch 156/200
# 120/120 - 0s - loss: 0.4900 - accuracy: 0.8417
# Epoch 157/200
# 120/120 - 0s - loss: 0.4884 - accuracy: 0.8500
# Epoch 158/200
# 120/120 - 0s - loss: 0.4886 - accuracy: 0.8333
# Epoch 159/200
# 120/120 - 0s - loss: 0.4874 - accuracy: 0.8500
# Epoch 160/200
# 120/120 - 0s - loss: 0.4861 - accuracy: 0.8583
# Epoch 161/200
# 120/120 - 0s - loss: 0.4856 - accuracy: 0.8250
# Epoch 162/200
# 120/120 - 0s - loss: 0.4834 - accuracy: 0.8417
# Epoch 163/200
# 120/120 - 0s - loss: 0.4834 - accuracy: 0.8333
# Epoch 164/200
# 120/120 - 0s - loss: 0.4831 - accuracy: 0.8333
# Epoch 165/200
